# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from oceantracker.post_processing.read_output_files import load_output_files
from oceantracker.post_processing.plotting import plot_tracks
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 16 from C header, got 88 from PyObject
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
path_to_dir = '/scratch/local1/output/22_07_19_test_stranded_particles_v01'
cases = load_output_files.get_case_info_files_from_dir(path_to_dir)
track = load_output_files.load_particle_track_vars(cases[0])
plot_tracks.animate_particles(track)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
