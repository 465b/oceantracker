# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# read csv data set
df = pd.read_csv('/home/zmaw/u301513/Documents/scr/phd/bicest/oceantracker/experiments/auxiliaries/ems_data_screening_from_gesa/202006_Ems_GesaSchulz.csv',delimiter=';')
# Out:
# str

# %%
# clean up data

# split away the last two rows for seperate processing
df1 = df.iloc[:-2]
df2 = df.iloc[-2:]

# turn 'timestamp' data into datetime format (11.06.2020 06:00)
df1.loc[:,'Timestamp'] = pd.to_datetime(df1['Timestamp'], format='%d.%m.%Y %H:%M')
# turn 'timestamp' data into datetime format (11.06.2020)
df2.loc[:,'Timestamp'] = pd.to_datetime(df2['Timestamp'], format='%d.%m.%Y')

# merge both back into df
df = pd.concat([df1,df2])

# sort data based on Ems km
df = df.sort_values(by=['Ems km'])

df
# Out:
# /home/zmaw/u301513/.conda/envs/oceantracker/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#              Timestamp  Station   Ems km   Latitude  Longitude   Salinity  \
# 26 2020-06-11 00:00:00      713  -13.783  53.031605   7.314106   0.000000
# 25 2020-06-11 00:00:00      712   -9.013  53.063270   7.283216   0.000000
# 11 2020-06-11 10:10:00      711    0.728  53.109175   7.366314   0.549250
# 10 2020-06-11 09:50:00      710    5.557  53.137997   7.368389   0.557300
# 9  2020-06-11 09:30:00      709    7.869  53.173324   7.373413   0.559900
# 8  2020-06-11 09:10:00      708   12.710  53.201129   7.410562   0.665500
# ...

# %%
# plot scatter data with lon lat as x and y and chlorophyll as color

fig,ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Longitude'],df['Latitude'],c=df['Chla..µg.l.'],s=20)

# %%
# plot Chla..µg.l. data vs Ems km

fig,ax = plt.subplots(figsize=(10,10))
ax.plot(df['Ems km'],df['Chla..µg.l.'], marker='o', linestyle='--')
ax.plot(df['Ems km'],df['Turbidity'], marker='o', linestyle='--')
# ax.plot(df['Ems km'],df['SPM..mg.l.']/10, marker='o', linestyle='--')
