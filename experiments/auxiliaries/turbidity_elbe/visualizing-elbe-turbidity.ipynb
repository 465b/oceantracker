# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime
sns.set_context('talk')

# %%
bunthaus = pd.read_csv('dbe_gast_20221114_151817887.csv',delimiter=';',quotechar="'")
seemanshoeft = pd.read_csv('dbe_gast_20221114_152318863.csv',delimiter=';',quotechar="'")

df = pd.concat([bunthaus,seemanshoeft])
df['Stromkilometer'] = [float(item.replace(',','.')) for item in df['Stromkilometer']]
df['Messwert'] = [float(item.replace(',','.')) for item in df['Messwert']]
df['Datum'] = pd.to_datetime(df['Datum'],format="%d.%m.%Y")

# %%
plt.figure(figsize=(20,10))
plt.grid(True)

dend = datetime.datetime(2012,1,1)
dstart = datetime.datetime(2013,1,1)

plt.scatter(bunthaus['Datum'],bunthaus['Messwert'],label='bunthaus',s=5)
plt.scatter(seemanshoeft['Datum'],seemanshoeft['Messwert'],label='seemanshöft',s=5)
plt.legend()
plt.xlim(dstart,dend)
plt.ylabel('FNU')
plt.savefig('long_term_turbidiy.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/category.py:68, in StrCategoryConverter.convert(value, unit, axis)
#      67 # force an update so it also does type checking
# ---> 68 unit.update(values)
#      69 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/category.py:227, in UnitData.update(self, data)
#     225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
# --> 227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
# ...

# %%
plt.figure(figsize=(20,10))
plt.grid(True)



dend = datetime.datetime(2022,1,1)
dstart = datetime.datetime(2010,1,1)

plt.scatter(bunthaus['Datum'],bunthaus['Messwert'],label='bunthaus',s=5)
plt.scatter(seemanshoeft['Datum'],seemanshoeft['Messwert'],label='seemanshöft',s=5)
plt.legend()
plt.xlim(dstart,dend)
plt.ylabel('FNU')
plt.savefig('long_term_turbidiy.png')

# %%
sns.boxplot(
    data=df,
    x='Stromkilometer',
    y='Messwert',
    whis=10
)
plt.grid(True)
plt.title('1996-2021')
# Out:
# Text(0.5, 1.0, '1996-2021')

# %%
seemanshoeft21 = seemanshoeft[(seemanshoeft['Datum'] > datetime.datetime(2021,1,1)) & (seemanshoeft['Datum'] < datetime.datetime(2022,1,1))]
seemanshoeft11 = seemanshoeft[(seemanshoeft['Datum'] > datetime.datetime(2011,1,1)) & (seemanshoeft['Datum'] < datetime.datetime(2012,1,1))]

# %%
sns.boxplot(
    data=df[(df['Datum'] > datetime.datetime(2021,1,1)) & (df['Datum'] < datetime.datetime(2022,1,1))],
    x='Stromkilometer',
    y='Messwert',
    whis=10
)
plt.grid(True)
plt.title('2021')
# Out:
# Text(0.5, 1.0, '2021')

# %%
plt.scatter(seemanshoeft11['Datum'],bunthaus11['Messwert'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 plt.scatter(seemanshoeft11['Datum'],bunthaus11['Messwert'])
#
# NameError: name 'bunthaus11' is not defined

# %%
sns.boxplot(data=bunthaus, x='Stromkilometer')
# Out:
# <AxesSubplot:xlabel='Stromkilometer'>

# %%
bunthaus['Stromkilometer'] = [float(item.replace(',','.')) for item in bunthaus['Stromkilometer']]

# %%
df = bunthaus.conc(seemanshoeft)
# Out:
# /tmp/ipykernel_3192/3018954732.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = bunthaus.append(seemanshoeft)

# %%
df =pd.concat([bunthaus,seemanshoeft])
df['Stromkilometer'] = [float(item.replace(',','.')) for item in df['Stromkilometer']]
sns.boxplot(data=df, x='Stromkilometer')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <module>
#       1 df =pd.concat([bunthaus,seemanshoeft])
# ----> 2 df['Stromkilometer'] = [float(item.replace(',','.')) for item in df['Stromkilometer']]
#       3 sns.boxplot(data=df, x='Stromkilometer')
#
# Input In [40], in <listcomp>(.0)
#       1 df =pd.concat([bunthaus,seemanshoeft])
# ----> 2 df['Stromkilometer'] = [float(item.replace(',','.')) for item in df['Stromkilometer']]
#       3 sns.boxplot(data=df, x='Stromkilometer')
#
# AttributeError: 'float' object has no attribute 'replace'
